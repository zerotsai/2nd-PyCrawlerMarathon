# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？

import requests,json

r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text
datas = json.loads(response)
print("回傳數量 :",len(datas))
print(datas)
# Out:
# 回傳數量 : 30
# [{'id': 233296131, 'title': '（更)台中黃金獵犬天堂💗', 'excerpt': '過年的時候發現這個地（天）方（堂）！！，一開始去的時候人還沒有到很～多，直接待快四個小時待好待滿，被這10隻大黃金+一隻臘腸逗得心花怒放的，老闆人也很親切很熱情，如果太調皮的～～就會被抓去關！禁！閉！', 'anonymousSchool': False, 'anonymousDepartment': True, 'pinned': False, 'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49', 'replyId': None, 'createdAt': '2020-03-19T07:28:28.449Z', 'updatedAt': '2020-03-19T11:27:17.773Z', 'commentCount': 40, 'likeCount': 453, 'withNickname': False, 'tags': [], 'topics': ['黃金', '獵犬', '狗', '寵物'], 'meta': {'layout': 'classic'}, 'forumName': '寵物', 'forumAlias': 'pet', 'gender': 'F', 'school': '朝陽科技大學', 'replyTitle': None, 'mediaMeta': [{'id': '2eeeac53-47b0-4e82-b905-0084deeeb4ae', 'url': 'https://vivid.dcard.tw/Public/8e8faadf-420d-46a2-9817-fd245d7bcced/thumbnail.jpg', 'normalizedUrl': 'https://vivid.dcard.tw/Public/8e8faadf-420d-46a2-9817-fd245d7bcced/thumbnail.jpg', 'thumbnail': 'https://vivid.dcard.tw/Public/8e8faadf-420d-46a2-9817-fd245d7bcced/thumbnail.jpg', 'type': 'image/thumbnail', 'tags': ['ANNOTATED_FAILED'], 'createdAt': '2020-03-19T07:28:28.449Z', 'updatedAt': '2020-03-19T11:27:17.773Z'}, {'id': '2eeeac53-47b0-4e82-b905-0084deeeb4ae', 'url': 'https://www.dcard.tw/v2/vivid/videos/8e8faadf-420d-46a2-9817-fd245d7bcced?r=1.7777777777777777', 'normalizedUrl': '', 'thumbnail': 'https://vivid.dcard.tw/Public/8e8faadf-420d-46a2-9817-fd245d7bcced/thumbnail.jpg', 'type': 'video/vivid', 'tags': ['ANNOTATED_FAILED'], 'createdAt': '2020-03-19T07:28:28.449Z', 'updatedAt': '2020-03-19T11:27:17.773Z'}, {'id': '40248c4a-8df0-46dc-85ee-177c1b95e71e', 'url': 'https://www.dcard.tw/v2/vivid/videos/5eb5f5ef-b825-4e81-8db1-7e18ea81186b?r=1.7777777777777777', 'normalizedUrl': '', 'thumbnail': 'https://vivid.dcard.tw/Public/5eb5f5ef-b825-4e81-8db1-7e18ea81186b/thumbnail.jpg', 'type': 'video/vivid', 'tags': [], 'createdAt': '2020-03-19T11:27:17.773Z', 'updatedAt': '2020-03-19T11:27:17.773Z'}, {'id': 'ed20acab-ffcb-4214-930d-361f70493a12', 'url': 'https://www.dcard.tw/v2/vivid/videos/38004a48-052a-4adf-b1ff-9fc63b02ccb3?r=1.7777777777777777', 'normalizedUrl': '', 'thumbnail': 'https://vivid.dcard.tw/Public/38004a48-052a-4adf-b1ff-9fc63b02ccb3/thumbnail.jpg', 'type': 'video/vivid', 'tags': [], 'createdAt': '2020-03-19T11:27:17.773Z', 'updatedAt': '2020-03-19T11:27:17.773Z'}, {'id': 'ce58668f-1de4-49fc-adaf-54ec7d1d18bc', 'url': 'https://megapx-assets.dcard.tw/images/925e31bd-7817-43e7-ac1f-d6d111810169/full.jpeg', 'normalizedUrl': 'https://megapx.dcard.tw/v1/images/925e31bd-7817-43e7-ac1f-d6d111810169', 'thumbnail': 'https://megapx-assets.dcard.tw/images/925e31bd-7817-43e7-ac1f-d6d111810169/320.jpeg', 'type': 'image/megapx', 'tags': ['ANNOTATED'], 'createdAt': '2020-03-19T07:28:28.449Z', 'updatedAt': '2020-03-19T11:27:17.773Z', 'width': 750, 'height': 954}, {'id': '7b25e683-5721-4e1d-958d-690a608dbe85', 'url': 'https://megapx-assets.dcard.tw/images/ca195713-bb81-4bd2-8d30-79d42e5cf0c2/640.jpeg', 'normalizedUrl': 'https://megapx.dcard.tw/v1/images/ca195713-bb81-4bd2-8d30-79d42e5cf0c2', 'thumbnail': 'https://megapx-assets.dcard.tw/images/ca195713-bb81-4bd2-8d30-79d42e5cf0c2/320.jpeg', 'type': 'image/megapx', 'tags': ['ANNOTATED'], 'createdAt': '2020-03-19T07:28:28.449Z', 'updatedAt': '2020-03-19T11:27:17.773Z', 'width': 2000, 'height': 1500}, {'id': '7ee8ff82-ee9b-4694-9efc-fba099e8529e', 'url': 'https://megapx-assets.dcard.tw/images/4a013ed2-0b53-444d-92fb-69000f5479bf/640.jpeg', 'normalizedUrl': 'https://megapx.dcard.tw/v1/images/4a013ed2-0b53-444d-92fb-69000f5479bf', 'thumbnail': 'https://megapx-assets.dcard.tw/images/4a013ed2-0b53-444d-92fb-69000f5479bf/320.jpeg', 'type': 'image/megapx', 'tags': [], 'createdAt': '2020-03-19T11:27:17.773Z', 'updatedAt': '2020-03-19T11:27:17.773Z', 'width': 1500, 'height': 2000}], 'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 453}], 'hidden': False, 'customStyle': None, 'isSuspiciousAccount': False, 'layout': 'classic', 'withImages': True, 'withVideos': True, 'media': [{'url': 'https://vivid.dcard. ...

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」

for data in datas:
    nun = len(data)
    print(data['title'])
# Out:
# （更)台中黃金獵犬天堂💗
# 師大虐狗朱女領養貓？
# 是黃金獵犬 不是拉不拉多啦🐾
# 憨吉的各種表情包
# 嗚嗚對不起我不該偷拍你的
# 手手呢ಠ_ಠ
# #電繪 寵物畫像
# 兔子的舌頭有多大👅
# 當你不再家，家裡的寵物在...
# 跟哥哥姐姐說你賣什麼
# 有誰家的天使貓走丟嗎？
# 睡到壞掉的柴柴
# 當有了一隻像貴婦的狗
# 清大烏龜來不及產卵，遭輾斃😭
# 拍三小！？
# 求主子照片多一點
# 你的頭怎麼卡住了🤣
# 犬種介紹特輯15 衝鋒車 羅威那~
# 我的「命」被妳救了..
# 沉重的愛
# 素顏
# 小弟-提摩
# 養爬蟲是一種成就（圖多）
# 長輩對養貓的反應
# 我家的新成員
# #狗 標準型貴賓的巨變日記 03
# 挑食的黃金鼠🐹
# 不被寵幸的妃子
# 給。我。飯。
# 是隻熊還是隻狗🐶

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

for data in datas:
    nun = len(data)
    print(data['title'])
# Out:
# （更)台中黃金獵犬天堂💗
# 師大虐狗朱女領養貓？
# 是黃金獵犬 不是拉不拉多啦🐾
# 憨吉的各種表情包
# 嗚嗚對不起我不該偷拍你的
# 手手呢ಠ_ಠ
# #電繪 寵物畫像
# 兔子的舌頭有多大👅
# 當你不再家，家裡的寵物在...
# 跟哥哥姐姐說你賣什麼
# 有誰家的天使貓走丟嗎？
# 睡到壞掉的柴柴
# 當有了一隻像貴婦的狗
# 清大烏龜來不及產卵，遭輾斃😭
# 拍三小！？
# 求主子照片多一點
# 你的頭怎麼卡住了🤣
# 犬種介紹特輯15 衝鋒車 羅威那~
# 我的「命」被妳救了..
# 沉重的愛
# 素顏
# 小弟-提摩
# 養爬蟲是一種成就（圖多）
# 長輩對養貓的反應
# 我家的新成員
# #狗 標準型貴賓的巨變日記 03
# 挑食的黃金鼠🐹
# 不被寵幸的妃子
# 給。我。飯。
# 是隻熊還是隻狗🐶
